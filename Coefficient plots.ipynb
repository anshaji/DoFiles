# %%
import matplotlib.pyplot as plt
import numpy as np

# Coefficients and standard errors for 'recent_firstborn_daughter'
coefficients = [0.040, 0.041, 0.099, 0.099, -0.040, -0.040]
std_errors = [0.014, 0.014, 0.012, 0.012, 0.014, 0.014]

# Model names
models = [
    "Ideal # Children\nNo Demographics",
    "Ideal # Children\nWith Demographics",
    "Ideal # Girls\nNo Demographics",
    "Ideal # Girls\nWith Demographics",
    "Ideal # Boys\nNo Demographics",
    "Ideal # Boys\nWith Demographics"
]

# Creating the plot
plt.figure(figsize=(10, 6))
x = np.arange(len(models))  # the label locations
width = 0.35  # the width of the bars

# Plotting bars
bars = plt.bar(x, coefficients, width, yerr=std_errors, capsize=5)

# Highlighting significant coefficients
for bar, coef in zip(bars, coefficients):
    if coef != 0:  # Assuming non-zero coefficients are significant
        bar.set_color('skyblue')
    else:
        bar.set_color('lightgray')

# labels & title
plt.ylabel('Coefficients')
plt.title('Effect of Recent Firstborn Daughter on Women\'s Fertility Preferences')
plt.xticks(x, models, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Women_fert_pref_plot.png')

plt.show()

# %%
# Coefficients and standard errors for the new regression results
coefficients_new = [0.049, 0.051, 0.097, 0.098, -0.029, -0.029]
std_errors_new = [0.015, 0.016, 0.013, 0.013, 0.015, 0.015]

# Creating the plot for the new coefficients
plt.figure(figsize=(10, 6))
x_new = np.arange(len(models))  # the label locations

# Plotting bars for the new regression results
bars_new = plt.bar(x_new, coefficients_new, width, yerr=std_errors_new, capsize=5)

# Highlighting significant coefficients
for bar, coef in zip(bars_new, coefficients_new):
    if coef != 0:  # Assuming non-zero coefficients are significant
        bar.set_color('lightgreen')
    else:
        bar.set_color('lightgray')

# labels & title
plt.ylabel('Coefficients')
plt.title('Effect of Recent Firstborn Daughter on Women\'s Fertility Preferences (High Fertility Countries)')
plt.xticks(x_new, models, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Viz/Women_highfert_countries.png')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Coefficients and standard errors for the third set of regression results
coefficients_third = [0.023, 0.020, 0.116, 0.120, -0.080, -0.075]
std_errors_third = [0.033, 0.031, 0.027, 0.027, 0.034, 0.034]

# Model names (remains the same as before)
models = [
    "Ideal # Children\nNo Demographics",
    "Ideal # Children\nWith Demographics",
    "Ideal # Girls\nNo Demographics",
    "Ideal # Girls\nWith Demographics",
    "Ideal # Boys\nNo Demographics",
    "Ideal # Boys\nWith Demographics"
]

# Creating the plot for the third set of coefficients
plt.figure(figsize=(10, 6))
x_third = np.arange(len(models))  # the label locations
width = 0.35  # the width of the bars

# Plotting bars for the third set of regression results
bars_third = plt.bar(x_third, coefficients_third, width, yerr=std_errors_third, capsize=5)

# Highlighting significant coefficients with color coding
for bar, coef in zip(bars_third, coefficients_third):
    if coef != 0:  # Assuming non-zero coefficients are significant
        if '***' in str(coef):  # Highly significant
            bar.set_color('salmon')
        elif '**' in str(coef):  # Moderately significant
            bar.set_color('lightcoral')
        elif '*' in str(coef):  # Marginally significant
            bar.set_color('peachpuff')
    else:
        bar.set_color('lightgray')

# Adding some text for labels, title and custom x-axis tick labels, etc.
plt.ylabel('Coefficients')
plt.title('Effect of Recent Firstborn Daughter on Women\'s Fertility Preferences (Low Fertility Countries)')
plt.xticks(x_third, models, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Viz/Women_lowfert_countries.png')

plt.show()

# %%
# Coefficients and standard errors for the new regression results (second set)
coefficients_new = [0.049, 0.051, 0.097, 0.098, -0.029, -0.029]
std_errors_new = [0.015, 0.016, 0.013, 0.013, 0.015, 0.015]

# Coefficients and standard errors for the third set of regression results
coefficients_third = [0.023, 0.020, 0.116, 0.120, -0.080, -0.075]
std_errors_third = [0.033, 0.031, 0.027, 0.027, 0.034, 0.034]

# Creating a comparison plot
plt.figure(figsize=(12, 7))
x = np.arange(len(models))  # the label locations
width = 0.35  # the width of the bars

# Plotting bars for the new (second set) regression results
bars_new = plt.bar(x - width/2, coefficients_new, width, yerr=std_errors_new, capsize=5, label='High Fertility Countries')

# Plotting bars for the third set of regression results
bars_third = plt.bar(x + width/2, coefficients_third, width, yerr=std_errors_third, capsize=5, label='Low Fertility Countries')

# Adding some text for labels, title, and custom x-axis tick labels, etc.
plt.ylabel('Coefficients')
plt.title('Comparison of Effects on Women\'s Fertility Preferences (High vs Low Fertility Countries)')
plt.xticks(x, models, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Viz/women_highvslow_countries.png')

plt.show()

# %%
# Coefficients and standard errors for the fourth set of regression results
coefficients_fourth = [0.017, 0.013, 0.045, 0.045, -0.028, -0.026]
std_errors_fourth = [0.031, 0.031, 0.023, 0.023, 0.026, 0.025]

# Creating the plot for the fourth set of coefficients
plt.figure(figsize=(10, 6))
x_fourth = np.arange(len(models))  # the label locations

# Plotting bars for the fourth set of regression results
bars_fourth = plt.bar(x_fourth, coefficients_fourth, width, yerr=std_errors_fourth, capsize=5)

# Highlighting significant coefficients with color coding
for bar, coef in zip(bars_fourth, coefficients_fourth):
    if coef != 0:  # Assuming non-zero coefficients are significant
        if '***' in str(coef):  # Highly significant
            bar.set_color('lightblue')
        elif '**' in str(coef):  # Moderately significant
            bar.set_color('powderblue')
        elif '*' in str(coef):  # Marginally significant
            bar.set_color('lavender')
    else:
        bar.set_color('lightgray')

# Adding some text for labels, title and custom x-axis tick labels, etc.
plt.ylabel('Coefficients')
plt.title('Effect of Recent Firstborn Daughter on Women\'s Fertility Preferences (High Fertility Individuals)')
plt.xticks(x_fourth, models, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Viz/women_highfert_indv.png')

plt.show()

# %%
# Coefficients and standard errors for the fifth set of regression results
coefficients_fifth = [0.021, 0.022, 0.111, 0.111, -0.054, -0.054]
std_errors_fifth = [0.008, 0.008, 0.013, 0.013, 0.013, 0.013]

# Creating the plot for the fifth set of coefficients
plt.figure(figsize=(10, 6))
x_fifth = np.arange(len(models))  # the label locations

# Plotting bars for the fifth set of regression results
bars_fifth = plt.bar(x_fifth, coefficients_fifth, width, yerr=std_errors_fifth, capsize=5)

# Highlighting significant coefficients with color coding
for bar, coef in zip(bars_fifth, coefficients_fifth):
    if coef != 0:  # Assuming non-zero coefficients are significant
        if '***' in str(coef):  # Highly significant
            bar.set_color('lightgreen')
        elif '**' in str(coef):  # Moderately significant
            bar.set_color('palegreen')
        elif '*' in str(coef):  # Marginally significant
            bar.set_color('honeydew')
    else:
        bar.set_color('lightgray')

# Adding some text for labels, title and custom x-axis tick labels, etc.
plt.ylabel('Coefficients')
plt.title('Effect of Recent Firstborn Daughter on Women\'s Fertility Preferences (Low Fertility Individuals)')
plt.xticks(x_fifth, models, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Viz/women_lowfert_indv.png')

plt.show()

# %%
# Coefficients and standard errors for High Fert Indv
coefficients_fourth = [0.017, 0.013, 0.045, 0.045, -0.028, -0.026]
std_errors_fourth = [0.031, 0.031, 0.023, 0.023, 0.026, 0.025]

# Coefficients and standard errors for Low Fert Indv
coefficients_fifth = [0.021, 0.022, 0.111, 0.111, -0.054, -0.054]
std_errors_fifth = [0.008, 0.008, 0.013, 0.013, 0.013, 0.013]

# Creating a comparison plot for High vs Low Fert Indv
plt.figure(figsize=(12, 7))
x_comparison = np.arange(len(models))  # the label locations

# Plotting bars for the fourth set of regression results
bars_fourth = plt.bar(x_comparison - width/2, coefficients_fourth, width, yerr=std_errors_fourth, capsize=5, label='High Fertility Individuals')

# Plotting bars for the fifth set of regression results
bars_fifth = plt.bar(x_comparison + width/2, coefficients_fifth, width, yerr=std_errors_fifth, capsize=5, label='Low Fertility Individuals')

# Adding some text for labels, title, and custom x-axis tick labels, etc.
plt.ylabel('Coefficients')
plt.title('Comparison of Effects on Women\'s Fertility Preferences (High vs Low Individuals)')
plt.xticks(x_comparison, models, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Viz/women_highvslowfert_indv.png')

plt.show()

# %%
# Coefficients and standard errors for the regression results focusing on different age ranges
coefficients_age_ranges = [0.086, 0.104, 0.102, 0.069, 0.187, 0.301]
std_errors_age_ranges = [0.018, 0.017, 0.026, 0.076, 0.107, 0.224]

# Age range categories
age_ranges = [
    "Age 15-20",
    "Age 21-25",
    "Age 26-30",
    "Age 31-35",
    "Age 36-40",
    "Over 40"
]

# Creating the plot for different age ranges
plt.figure(figsize=(10, 6))
x_age_ranges = np.arange(len(age_ranges))  # the label locations

# Plotting bars for the different age ranges
bars_age_ranges = plt.bar(x_age_ranges, coefficients_age_ranges, width, yerr=std_errors_age_ranges, capsize=5)

# Highlighting significant coefficients with color coding
for bar, coef in zip(bars_age_ranges, coefficients_age_ranges):
    if coef != 0:  # Assuming non-zero coefficients are significant
        if '***' in str(coef):  # Highly significant
            bar.set_color('orchid')
        elif '**' in str(coef):  # Moderately significant
            bar.set_color('plum')
        elif '*' in str(coef):  # Marginally significant
            bar.set_color('thistle')
    else:
        bar.set_color('lavender')

# Adding some text for labels, title and custom x-axis tick labels, etc.
plt.ylabel('Coefficients')
plt.title('Effect of Recent Firstborn Daughter on Ideal Number of Girls by Age Range')
plt.xticks(x_age_ranges, age_ranges, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Viz/idealgirls_age.png')

plt.show()

# %%
# Coefficients and standard errors for the regression results focusing on ideal number of boys across different age ranges
coefficients_boys_age_ranges = [-0.041, -0.029, -0.016, -0.097, -0.141, -0.449]
std_errors_boys_age_ranges = [0.023, 0.018, 0.027, 0.081, 0.095, 0.198]

# Creating the plot for different age ranges for ideal number of boys
plt.figure(figsize=(10, 6))
x_boys_age_ranges = np.arange(len(age_ranges))  # the label locations

# Plotting bars for the different age ranges for ideal number of boys
bars_boys_age_ranges = plt.bar(x_boys_age_ranges, coefficients_boys_age_ranges, width, yerr=std_errors_boys_age_ranges, capsize=5)

# Highlighting significant coefficients with color coding
for bar, coef in zip(bars_boys_age_ranges, coefficients_boys_age_ranges):
    if coef != 0:  # Assuming non-zero coefficients are significant
        if '***' in str(coef):  # Highly significant
            bar.set_color('cornflowerblue')
        elif '**' in str(coef):  # Moderately significant
            bar.set_color('lightsteelblue')
        elif '*' in str(coef):  # Marginally significant
            bar.set_color('lavender')
    else:
        bar.set_color('lightgray')

# Adding some text for labels, title and custom x-axis tick labels, etc.
plt.ylabel('Coefficients')
plt.title('Effect of Recent Firstborn Daughter on Ideal Number of Boys by Age Range')
plt.xticks(x_boys_age_ranges, age_ranges, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Viz/idealboys_age.png')

plt.show()

# %%
# Combining the coefficients and standard errors for ideal number of girls and boys across different age ranges for comparison
coefficients_girls = [0.086, 0.104, 0.102, 0.069, 0.187, 0.301]
std_errors_girls = [0.018, 0.017, 0.026, 0.076, 0.107, 0.224]
coefficients_boys = [-0.041, -0.029, -0.016, -0.097, -0.141, -0.449]
std_errors_boys = [0.023, 0.018, 0.027, 0.081, 0.095, 0.198]

# Creating a comparison plot for ideal number of girls and boys across different age ranges
plt.figure(figsize=(12, 7))
x_combined = np.arange(len(age_ranges))  # the label locations

# Plotting bars for ideal number of girls
bars_girls = plt.bar(x_combined - width/2, coefficients_girls, width, yerr=std_errors_girls, capsize=5, label='Ideal Number of Girls', color='orchid')

# Plotting bars for ideal number of boys
bars_boys = plt.bar(x_combined + width/2, coefficients_boys, width, yerr=std_errors_boys, capsize=5, label='Ideal Number of Boys', color='cornflowerblue')

# Adding some text for labels, title, and custom x-axis tick labels, etc.
plt.ylabel('Coefficients')
plt.title('Comparison of Effects on Ideal Number of Girls and Boys by Age Range')
plt.xticks(x_combined, age_ranges, rotation=45, ha="right")
plt.axhline(0, color='gray', linewidth=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Displaying the plot
plt.tight_layout()
plt.savefig('/Users/akashshaji/Desktop/fert_pref/Viz/ideal_boysvsgirls_age.png')

plt.show()
